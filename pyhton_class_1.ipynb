# %% [markdown]
# <a href="https://colab.research.google.com/github/mkgopal089-code/python-from-basic/blob/main/pyhton_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Gopal")
# Out:
# Gopal

# %%
print("5" + "5")
# Out:
# 55

# %%
print(5 +int("5"))
# Out:
# 10

# %%
print(5 + "5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2605/2189679914.py in <cell line: 0>()
# ----> 1 print(5 + "5")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(str(5) + "5")
# Out:
# 55

# %%
print()

# %%
print("hi" * 3)
# Out:
# hihihi

# %%
print("Welcome to python Programming")
print("Let's start our coding journey")
# Out:
# Welcome to python Programming
# Let's start our coding journey

# %%
print('let's start our coding journey')
# Out:
#   File "/tmp/ipykernel_2605/5645024.py", line 1
#     print('let's start our coding journey')
#                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("*" * 10)

print("My Profile")


print("*" * 10)


print("Name: Harsh Gopal")


print("Role: Student")


print("Interest: Data Science AI & ML")
# Out:
# **********
# My Profile
# **********
# Name: Harsh Gopal
# Role: Student
# Interest: Data Science AI & ML

# %%
print("*" * 1)
print("*" * 2)
print("*" * 3)
print("*" * 4)
print("*" * 5)
# Out:
# *
# **
# ***
# ****
# *****

# %%
print("*" * 10 + "INVOICE" + "*" * 10)
print("Product: Laptop")
print("Price: 100000000000")
print("gst: 10000000")
print("Total: 10000000000000000000")
print("*" * 20)
# Out:
# **********INVOICE**********
# Product: Laptop
# Price: 100000000000
# gst: 10000000
# Total: 10000000000000000000
# ********************

# %%
print("**********INVOICE**********","Product: Laptop","Price: 100000000000","Gst: 1000000",sep="\n")
# Out:
# **********INVOICE**********
# Product: Laptop
# Price: 100000000000
# Gst: 1000000
