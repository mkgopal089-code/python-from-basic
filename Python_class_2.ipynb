# %% [markdown]
# <a href="https://colab.research.google.com/github/mkgopal089-code/python-from-basic/blob/main/Python_class_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Both output appear on the same line

# %%
print("Hello" , end =" ")
print("Pyhton")
# Out:
# Hello Pyhton

# %%
print("Hello" , end ="|")
print("Pyhton")
# Out:
# Hello|Pyhton

# %%
print("Hello" , end ="Python")
# Out:
# HelloPython

# %%
print(01,01,2007,sep="/")
# Out:
#   File "/tmp/ipykernel_845/1736648366.py", line 1
#     print(01,01,2007,sep="/")
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
print(1,1,2007,sep="/")
# Out:
# 1/1/2007

# %%
print(0o1,0o1,2007,sep="/")
# Out:
# 1/1/2007

# %%
print("01","01",2007,sep="/")
# Out:
# 01/01/2007

# %%
print("Rahul","101","CSE",sep="-")
# Out:
# Rahul-101-CSE

# %%
print("Maths 90"," Python 95"," AI 98",sep="|")
# Out:
# Maths 90| Python 95| AI 98
